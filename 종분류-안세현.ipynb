# %%
from PIL import Image
import os, glob, numpy as np
from sklearn.model_selection import train_test_split

caltech_dir = "./multi_img_data/imgs_others/train"
categories = ["Bombay", "Persian", "Rusianblue", "Siberia"]
nb_classes = len(categories)

image_w = 64
image_h = 64

pixels = image_h * image_w * 3

X = []
y = []

for idx, cat in enumerate(categories):
    
    #one-hot 돌리기.
    label = [0 for i in range(nb_classes)]
    label[idx] = 1

    image_dir = caltech_dir + "/" + cat
    files = glob.glob(image_dir+"/*.jpg")
    print(cat, " 파일 길이 : ", len(files))
    for i, f in enumerate(files):
        img = Image.open(f)
        img = img.convert("RGB")
        img = img.resize((image_w, image_h))
        data = np.asarray(img)

        X.append(data)
        y.append(label)

        if i % 700 == 0:
            print(cat, " : ", f)

X = np.array(X)
y = np.array(y)
#1 0 0 0 이면 airplanes
#0 1 0 0 이면 buddha 이런식


X_train, X_test, y_train, y_test = train_test_split(X, y)
xy = (X_train, X_test, y_train, y_test)
np.save("./numpy_data/multi_image_data.npy", xy)

print("ok", len(y))
# Out:
# Bombay  파일 길이 :  499
# Bombay  :  ./multi_img_data/imgs_others/train/Bombay\bombay001.jpg
# Persian  파일 길이 :  300
# Persian  :  ./multi_img_data/imgs_others/train/Persian\persian1.jpg
# Rusianblue  파일 길이 :  2262
# Rusianblue  :  ./multi_img_data/imgs_others/train/Rusianblue\Rusianblue(1).jpg
# Rusianblue  :  ./multi_img_data/imgs_others/train/Rusianblue\Rusianblue(1629).jpg
# Rusianblue  :  ./multi_img_data/imgs_others/train/Rusianblue\Rusianblue(2259).jpg
# Rusianblue  :  ./multi_img_data/imgs_others/train/Rusianblue\Rusianblue(853).jpg
# Siberia  파일 길이 :  179
# Siberia  :  ./multi_img_data/imgs_others/train/Siberia\Siberia (1).jpg
# ok 3240

# %%
import os, glob, numpy as np
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt
import keras.backend.tensorflow_backend as K

import tensorflow as tf
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
session = tf.compat.v1.Session(config=config)

import numpy as np

## 먼저 기존의 np.load를 np_load_old에 저장해둠.
np_load_old = np.load

## 기존의 parameter을 바꿔줌
np.load = lambda *a,**k: np_load_old(*a,allow_pickle=True)
X_train, X_test, y_train, y_test = np.load('./numpy_data/multi_image_data.npy')
print(X_train.shape)
print(X_train.shape[0])
# Out:
# Using TensorFlow backend.
# (2430, 64, 64, 3)
# 2430

# %%
categories = ["Bombay", "Persian", "Rusianblue", "Siberia"]
nb_classes = len(categories)

#일반화
X_train = X_train.astype(float) / 255
X_test = X_test.astype(float) / 255

# %%
with K.tf_ops.device('/device:GPU:0'):
    model = Sequential()
    model.add(Conv2D(32, (3,3), padding="same", input_shape=X_train.shape[1:], activation='relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.2))
    
    model.add(Conv2D(64, (3,3), padding="same", activation='relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.2))
    
    model.add(Conv2D(128, (3,3), padding="same", activation='relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.2))
    
    model.add(Conv2D(256, (3,3), padding="same", activation='relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.2))
    
    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(nb_classes, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    model_dir = './model'
    
    if not os.path.exists(model_dir):
        os.mkdir(model_dir)
    
    model_path = model_dir + '/multi_img_classification.model'
    checkpoint = ModelCheckpoint(filepath=model_path , monitor='val_loss', verbose=1, save_best_only=True)
    early_stopping = EarlyStopping(monitor='val_loss', patience=6)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 64, 64, 32)        896
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 16, 16, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 16384)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               4194560
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 1028
# =================================================================
# Total params: 4,214,980
# Trainable params: 4,214,980
# Non-trainable params: 0
# _________________________________________________________________

# %%
#데이터셋이 적어서 validation을 그냥 test 데이터로 했습니다. 
#데이터셋이 충분하시면 이렇게 하시지 마시고 validation_split=0.2 이렇게 하셔서 테스트 셋으로 나누시길 권장합니다.
history = model.fit(X_train, y_train, batch_size=32, epochs=50, validation_data=(X_test, y_test), callbacks=[checkpoint, early_stopping])
# Out:
# Train on 2430 samples, validate on 810 samples
# Epoch 1/50
# 2430/2430 [==============================] - 25s 10ms/step - loss: 0.9234 - accuracy: 0.7128 - val_loss: 0.7031 - val_accuracy: 0.8123
#
# Epoch 00001: val_loss improved from inf to 0.70315, saving model to ./model/multi_img_classification.model
# Epoch 2/50
# 2430/2430 [==============================] - 23s 10ms/step - loss: 0.5750 - accuracy: 0.8062 - val_loss: 0.5605 - val_accuracy: 0.8198
#
# Epoch 00002: val_loss improved from 0.70315 to 0.56049, saving model to ./model/multi_img_classification.model
# Epoch 3/50
# 2430/2430 [==============================] - 23s 10ms/step - loss: 0.5097 - accuracy: 0.8181 - val_loss: 0.4467 - val_accuracy: 0.8370
#
# Epoch 00003: val_loss improved from 0.56049 to 0.44670, saving model to ./model/multi_img_classification.model
# Epoch 4/50
# 2430/2430 [==============================] - 22s 9ms/step - loss: 0.4179 - accuracy: 0.8564 - val_loss: 0.3861 - val_accuracy: 0.8691
#
# Epoch 00004: val_loss improved from 0.44670 to 0.38605, saving model to ./model/multi_img_classification.model
# Epoch 5/50
# 2430/2430 [==============================] - 22s 9ms/step - loss: 0.3703 - accuracy: 0.8712 - val_loss: 0.3530 - val_accuracy: 0.8790
#
# Epoch 00005: val_loss improved from 0.38605 to 0.35301, saving model to ./model/multi_img_classification.model
# Epoch 6/50
# 2430/2430 [==============================] - 23s 9ms/step - loss: 0.3311 - accuracy: 0.8761 - val_loss: 0.3295 - val_accuracy: 0.9025
#
# Epoch 00006: val_loss improved from 0.35301 to 0.32946, saving model to ./model/multi_img_classification.model
# Epoch 7/50
# 2430/2430 [==============================] - 22s 9ms/step - loss: 0.2808 - accuracy: 0.8967 - val_loss: 0.2926 - val_accuracy: 0.8963
#
# Epoch 00007: val_loss improved from 0.32946 to 0.29265, saving model to ./model/multi_img_classification.model
# Epoch 8/50
# 2430/2430 [==============================] - 24s 10ms/step - loss: 0.2511 - accuracy: 0.9041 - val_loss: 0.2705 - val_accuracy: 0.9136
#
# Epoch 00008: val_loss improved from 0.29265 to 0.27053, saving model to ./model/multi_img_classification.model
# Epoch 9/50
# 2430/2430 [==============================] - 24s 10ms/step - loss: 0.2351 - accuracy: 0.9144 - val_loss: 0.2628 - val_accuracy: 0.9074
#
# Epoch 00009: val_loss improved from 0.27053 to 0.26281, saving model to ./model/multi_img_classification.model
# Epoch 10/50
# 2430/2430 [==============================] - 24s 10ms/step - loss: 0.2057 - accuracy: 0.9243 - val_loss: 0.2899 - val_accuracy: 0.9037
#
# Epoch 00010: val_loss did not improve from 0.26281
# Epoch 11/50
# 2430/2430 [==============================] - 23s 9ms/step - loss: 0.1861 - accuracy: 0.9309 - val_loss: 0.2678 - val_accuracy: 0.9111
#
# Epoch 00011: val_loss did not improve from 0.26281
# Epoch 12/50
# 2430/2430 [==============================] - 23s 10ms/step - loss: 0.1652 - accuracy: 0.9374 - val_loss: 0.3092 - val_accuracy: 0.9049
#
# Epoch 00012: val_loss did not improve from 0.26281
# Epoch 13/50
# 2430/2430 [==============================] - 24s 10ms/step - loss: 0.1304 - accuracy: 0.9481 - val_loss: 0.2730 - val_accuracy: 0.9160
#
# Epoch 00013: val_loss did not improve from 0.26281
# Epoch 14/50
# 2430/2430 [==============================] - 23s 9ms/step - loss: 0.1151 - accuracy: 0.9556 - val_loss: 0.2354 - val_accuracy: 0.9160
#
# Epoch 00014: val_loss improved from 0.26281 to 0.23539, saving model to ./model/multi_img_classification.model
# Epoch 15/50
# 2430/2430 [==============================] - 23s 9ms/step - loss: 0.1231 - accuracy: 0.9543 - val_loss: 0.2657 - val_accuracy: 0.9222
#
# Epoch 00015: val_loss did not improve from 0.23539
# Epoch 16/50
# 2430/2430 [==============================] - 23s 10ms/step - loss: 0.1102 - accuracy: 0.9601 - val_loss: 0.2864 - val_accuracy: 0.9235
#
# Epoch 00016: val_loss did not improve from 0.23539
# Epoch 17/50
# 2430/2430 [==============================] - 24s 10ms/step - loss: 0.0922 - accuracy: 0.9663 - val_loss: 0.2768 - val_accuracy: 0.9272
#
# Epoch 00017: val_loss did not improve from 0.23539
# Epoch 18/50
# 2430/2430 [==============================] - 22s 9ms/step - loss: 0.0999 - accuracy: 0.9663 - val_loss: 0.2658 - val_accuracy: 0.9173
#
# Epoch 00018: val_loss did not improve from 0.23539
# Epoch 19/50
# 2430/2430 [==============================] - 23s 9ms/step - loss: 0.0825 - accuracy: 0.9671 - val_loss: 0.2835 - val_accuracy: 0.9099
#
# Epoch 00019: val_loss did not improve from 0.23539
# Epoch 20/50
# 2430/2430 [==============================] - 24s 10ms/step - loss: 0.1242 - accuracy: 0.9556 - val_loss: 0.2914 - val_accuracy: 0.9185
#
# Epoch 00020: val_loss did not improve from 0.23539

# %%
print("정확도 : %.4f" % (model.evaluate(X_test, y_test)[1]))
# Out:
# 810/810 [==============================] - 2s 2ms/step
# 정확도 : 0.9185

# %%
y_vloss = history.history['val_loss']
y_loss = history.history['loss']

x_len = np.arange(len(y_loss))

plt.plot(x_len, y_vloss, marker='.', c='red', label='val_set_loss')
plt.plot(x_len, y_loss, marker='.', c='blue', label='train_set_oss')
plt.legend()
plt.xlabel('epochs')
plt.ylabel('loss')
plt.grid()
plt.show()

# %%
from PIL import Image
import os, glob, numpy as np
from keras.models import load_model

caltech_dir = "./multi_img_data/imgs_others/train/bombay"
image_w = 64
image_h = 64

pixels = image_h * image_w * 3

X = []
filenames = []
files = glob.glob(caltech_dir+"/*.jpg")
for i, f in enumerate(files):
    img = Image.open(f)
    img = img.convert("RGB")
    img = img.resize((image_w, image_h))
    data = np.asarray(img)
    filenames.append(f)
    X.append(data)

X = np.array(X)
model = load_model('./model/multi_img_classification.model')

prediction = model.predict(X)
np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})
cnt = 0

#이 비교는 그냥 파일들이 있으면 해당 파일과 비교. 카테고리와 함께 비교해서 진행하는 것은 _4 파일.
for i in prediction:
    pre_ans = i.argmax()  # 예측 레이블
    print(i)
    print(pre_ans)
    pre_ans_str = ''
    if pre_ans == 0: pre_ans_str = "Bombay"
    elif pre_ans == 1: pre_ans_str = "Persian"
    elif pre_ans == 2: pre_ans_str = "Rusianblue"
    else: pre_ans_str = "Siberia"
    if i[0] >= 0.8 : print("해당 "+filenames[cnt].split("\\")[1]+"이미지는 "+pre_ans_str+"로 추정됩니다.")
    if i[1] >= 0.8: print("해당 "+filenames[cnt].split("\\")[1]+"이미지는 "+pre_ans_str+"으로 추정됩니다.")
    if i[2] >= 0.8: print("해당 "+filenames[cnt].split("\\")[1]+"이미지는 "+pre_ans_str+"로 추정됩니다.")
    if i[3] >= 0.8: print("해당 "+filenames[cnt].split("\\")[1]+"이미지는 "+pre_ans_str+"로 추정됩니다.")
    cnt += 1
    # print(i.argmax()) #얘가 레이블 [1. 0. 0.] 이런식으로 되어 있는 것을 숫자로 바꿔주는 것.
    # 즉 얘랑, 나중에 카테고리 데이터 불러와서 카테고리랑 비교를 해서 같으면 맞는거고, 아니면 틀린거로 취급하면 된다.
    # 이걸 한 것은 _4.py에.
# Out:
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay001.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay002.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 0.000 1.000]
# 3
# 해당 bombay003.jpg이미지는 Siberia로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay004.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay005.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay006.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay007.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay008.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay009.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay010.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay011.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay012.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay013.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay014.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay015.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay016.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay017.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay018.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay019.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay020.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay021.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay022.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay023.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay024.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay025.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay026.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay027.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay028.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay029.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay030.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay031.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay032.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay033.jpg이미지는 Bombay로 추정됩니다.
# [0.000 1.000 0.000 0.000]
# 1
# 해당 bombay034.jpg이미지는 Persian으로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay035.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay036.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay037.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay038.jpg이미지는 Rusianblue로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay039.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay040.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay041.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay042.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay043.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay044.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay045.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay046.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay047.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay048.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay049.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay050.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay051.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay052.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay053.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay054.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay055.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay056.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay057.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay058.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 0.000 1.000]
# 3
# 해당 bombay059.jpg이미지는 Siberia로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay060.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay061.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay062.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay063.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay064.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay065.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay066.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay067.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay068.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay069.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay070.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay071.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay072.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay073.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay074.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay075.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay076.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay077.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay078.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay079.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay080.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay081.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay082.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay083.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay084.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay085.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay086.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay087.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay088.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay089.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay090.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay091.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay092.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay093.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay094.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay095.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay096.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay097.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay098.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay099.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay100.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 0.000 1.000]
# 3
# 해당 bombay101.jpg이미지는 Siberia로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay102.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay103.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay104.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay105.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay106.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay107.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay108.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay109.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay110.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay111.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay112.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay113.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay114.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay115.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 0.000 1.000]
# 3
# 해당 bombay116.jpg이미지는 Siberia로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay117.jpg이미지는 Rusianblue로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay118.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay119.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay120.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay121.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay122.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay123.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay124.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay125.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay126.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay127.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay128.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay129.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay130.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay131.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay132.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay133.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay134.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay135.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay136.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay137.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay138.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay139.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay140.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay141.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay142.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay143.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay144.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay145.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay146.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay147.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay148.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay149.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay150.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay151.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay152.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay153.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay154.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay155.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay156.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay157.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay158.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay159.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay160.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay161.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay162.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 0.000 1.000]
# 3
# 해당 bombay163.jpg이미지는 Siberia로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay164.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay165.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay166.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay167.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay168.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay169.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay170.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay171.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay172.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay173.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay174.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay175.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay176.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay177.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay178.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay179.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay180.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay181.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay182.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay183.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay184.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay185.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay186.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay187.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay188.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay189.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay190.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay191.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay192.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay193.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay194.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay195.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay196.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay197.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay198.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay199.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay200.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay201.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay202.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay203.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay204.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay205.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay206.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay207.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay208.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay209.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay210.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay211.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay212.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay213.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay214.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay215.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay216.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay217.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay218.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay219.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay220.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay221.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay222.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay223.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay224.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay225.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay226.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay227.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay228.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay229.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay230.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay231.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay232.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay233.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay234.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay235.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay236.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay237.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay238.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay239.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay240.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay241.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay242.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay243.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay244.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay245.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay246.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay247.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay248.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay249.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay250.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay251.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay252.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay253.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay254.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay255.jpg이미지는 Rusianblue로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay256.jpg이미지는 Rusianblue로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay257.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay258.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay259.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay260.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay261.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay262.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay263.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay264.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 0.000 1.000]
# 3
# 해당 bombay265.jpg이미지는 Siberia로 추정됩니다.
# [0.000 0.000 0.000 1.000]
# 3
# 해당 bombay266.jpg이미지는 Siberia로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay267.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay268.jpg이미지는 Rusianblue로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay269.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay270.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay271.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay272.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay273.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay274.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay275.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay276.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay277.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay278.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay279.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay280.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay281.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay282.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay283.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay284.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay285.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay286.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay287.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay288.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay289.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay290.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay291.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 0.000 1.000]
# 3
# 해당 bombay292.jpg이미지는 Siberia로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay293.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay294.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 0.000 1.000]
# 3
# 해당 bombay295.jpg이미지는 Siberia로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay296.jpg이미지는 Rusianblue로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay297.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay298.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay299.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay300.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay301.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay302.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay303.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay304.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay305.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay306.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay307.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay308.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay309.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay310.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay311.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 0.000 1.000]
# 3
# 해당 bombay312.jpg이미지는 Siberia로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay313.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 0.000 1.000]
# 3
# 해당 bombay314.jpg이미지는 Siberia로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay315.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay316.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay317.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay318.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay319.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay320.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay321.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay322.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 0.000 1.000]
# 3
# 해당 bombay323.jpg이미지는 Siberia로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay324.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay325.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay326.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay327.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay328.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay329.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay330.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay331.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay332.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay333.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay334.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay335.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay336.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay337.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay338.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay339.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay340.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay341.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay342.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay343.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay344.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay345.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay346.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay347.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay348.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay349.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay350.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay351.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay352.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay353.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay354.jpg이미지는 Rusianblue로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay355.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay356.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay357.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay358.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay359.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay360.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay361.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay362.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay363.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay364.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay365.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay366.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay367.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay368.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay369.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay370.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay371.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay372.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay373.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 0.000 1.000]
# 3
# 해당 bombay374.jpg이미지는 Siberia로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay375.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay376.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay377.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay378.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay379.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay380.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay381.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay382.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay383.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay384.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay385.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay386.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay387.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay388.jpg이미지는 Rusianblue로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay389.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay390.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay391.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay392.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay393.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay394.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay395.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay396.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay397.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay398.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay399.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay400.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 0.000 1.000]
# 3
# 해당 bombay401.jpg이미지는 Siberia로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay402.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay403.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay404.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay405.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay406.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay407.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay408.jpg이미지는 Rusianblue로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay409.jpg이미지는 Rusianblue로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay410.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay411.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay412.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay413.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay414.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay415.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay416.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay418.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 0.000 1.000]
# 3
# 해당 bombay419.jpg이미지는 Siberia로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay420.jpg이미지는 Rusianblue로 추정됩니다.
# [0.000 0.000 0.000 1.000]
# 3
# 해당 bombay421.jpg이미지는 Siberia로 추정됩니다.
# [0.000 0.000 0.000 1.000]
# 3
# 해당 bombay422.jpg이미지는 Siberia로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay423.jpg이미지는 Rusianblue로 추정됩니다.
# [0.000 0.000 0.000 1.000]
# 3
# 해당 bombay424.jpg이미지는 Siberia로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay425.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay426.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay427.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay428.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay429.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay430.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay431.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay432.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay433.jpg이미지는 Rusianblue로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay434.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay435.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay436.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay437.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay438.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay439.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay440.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay441.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay442.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay443.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay444.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay445.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay446.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay447.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay448.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay449.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay450.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay451.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay452.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay453.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay454.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay455.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay456.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay457.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay458.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay459.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay460.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay461.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay462.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay463.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay464.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay465.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay466.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay467.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay468.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay469.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay470.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay471.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay472.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay473.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay474.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay475.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay476.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 0.000 1.000]
# 3
# 해당 bombay477.jpg이미지는 Siberia로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay478.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay479.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay480.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay481.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay482.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay483.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay484.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay485.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay486.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay487.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay488.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay489.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay490.jpg이미지는 Bombay로 추정됩니다.
# [0.000 0.000 1.000 0.000]
# 2
# 해당 bombay491.jpg이미지는 Rusianblue로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay492.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay493.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay494.jpg이미지는 Bombay로 추정됩니다.
# [0.000 1.000 0.000 0.000]
# 1
# 해당 bombay495.jpg이미지는 Persian으로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay496.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay497.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay498.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay499.jpg이미지는 Bombay로 추정됩니다.
# [1.000 0.000 0.000 0.000]
# 0
# 해당 bombay500.jpg이미지는 Bombay로 추정됩니다.
